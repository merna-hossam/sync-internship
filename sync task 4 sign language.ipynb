# %% [markdown]
# # 1- Hello Friends
#
# **Hello Future Engineers, Nice to meet you!**

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (16,16))
img = plt.imread('/kaggle/input/sign-language-mnist/amer_sign2.png')
plt.imshow(img)
plt.show()

# %% [markdown]
# The dataset format is patterned to match closely with the classic MNIST. Each training and test case represents a label (0-25) as a one-to-one map for each alphabetic letter A-Z (and no cases for 9=J or 25=Z because of gesture motions). The training data (27,455 cases) and test data (7172 cases) are approximately half the size of the standard MNIST but otherwise similar with a header row of label, pixel1,pixel2….pixel784 which represent a single 28x28 pixel image with grayscale values between 0-255.

# %% [markdown]
# # 2- Import
# First we import our libraries that will we need.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import random
from sklearn.model_selection import train_test_split
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPool2D, Flatten, Dense, Dropout
import warnings

sns.set()
# %matplotlib inline
warnings.filterwarnings("ignore")

# %% [markdown]
# # 3- Prepare Data
# Import **train** and **test** data as dataframes.

# %%
df_train = pd.read_csv('../input/sign-language-mnist/sign_mnist_train/sign_mnist_train.csv')
df_train.head(-5)
# Out:
#        label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0          3     107     118     127     134     139     143     146     150
# 1          6     155     157     156     156     156     157     156     158
# 2          2     187     188     188     187     187     186     187     188
# 3          2     211     211     212     212     211     210     211     210
# 4         13     164     167     170     172     176     179     180     184
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 27445     14     167     169     170     171     171     172     172     172
# 27446     19     133     135     138     141     143     144     144     145
# 27447     11     170     172     175     177     179     182     185     186
# 27448     12     149     151     153     157     159     161     164     165
# 27449     20     162     168     172     176     179     183     184     185
#
#        pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  \
# 0         153  ...       207       207       207       207       206
# 1         158  ...        69       149       128        87        94
# 2         187  ...       202       201       200       199       198
# 3         210  ...       235       234       233       231       230
# 4         185  ...        92       105       105       108       133
# ...       ...  ...       ...       ...       ...       ...       ...
# 27445     171  ...       215       215       211       208       211
# 27446     145  ...         0         0         1         4         4
# 27447     187  ...       221       228       229       228       229
# 27448     168  ...       108       165       167       163       159
# 27449     188  ...       235       234       234       233       231
#
#        pixel780  pixel781  pixel782  pixel783  pixel784
# 0           206       206       204       203       202
# 1           163       175       103       135       149
# 2           199       198       195       194       195
# 3           226       225       222       229       163
# 4           163       157       163       164       179
# ...         ...       ...       ...       ...       ...
# 27445       201       167       119        75        48
# 27446         0         0         0         0         0
# 27447       229       227       228       227       227
# 27448       153       147       148       139       196
# 27449       229       228       228       227       226
#
# [27450 rows x 785 columns]

# %%
df_test = pd.read_csv('../input/sign-language-mnist/sign_mnist_test/sign_mnist_test.csv')
df_test.head(-5)
# Out:
#       label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0         6     149     149     150     150     150     151     151     150
# 1         5     126     128     131     132     133     134     135     135
# 2        10      85      88      92      96     105     123     135     143
# 3         0     203     205     207     206     207     209     210     209
# 4         3     188     191     193     195     199     201     202     203
# ...     ...     ...     ...     ...     ...     ...     ...     ...     ...
# 7162     10     130     131     131     134     133     135     137     136
# 7163      4     158     161     165     169     172     175     177     179
# 7164     14     141     144     146     149     153     156     158     161
# 7165      8     158     160     160     161     161     161     164     162
# 7166     12     169     173     177     181     183     186     189     191
#
#       pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 0        151  ...       138       148       127        89        82        96
# 1        136  ...        47       104       194       183       186       184
# 2        147  ...        68       166       242       227       230       227
# 3        210  ...       154       248       247       248       253       236
# 4        203  ...        26        40        64        48        29        46
# ...      ...  ...       ...       ...       ...       ...       ...       ...
# 7162     136  ...       128       106       107        63        11       147
# 7163     181  ...        78       122       141       141       141       140
# 7164     161  ...       199       203       202       201       201       201
# 7165     162  ...       177       178       176       174       173       172
# 7166     194  ...        36        27        14        35        40        15
#
#       pixel781  pixel782  pixel783  pixel784
# 0          106       112       120       107
# 1          184       184       182       180
# 2          226       225       224       222
# 3          230       240       253       255
# 4           49        46        46        53
# ...        ...       ...       ...       ...
# 7162       194       182       176       124
# 7163       141       142       143       144
# 7164       200       200       201       201
# 7165       171       169       169       167
# 7166         8        27        42        41
#
# [7167 rows x 785 columns]

# %% [markdown]
# The classes of data and their number of images.

# %%
plt.figure(figsize = (15,10))
sns.set_style("darkgrid")
sns.countplot(df_train['label'])
plt.show()

# %% [markdown]
# Let's split the **label** column from train and test data frames.

# %%
y_train = df_train['label']
df_train.drop(['label'], axis=1, inplace=True)
df_train.head(-5)
# Out:
#        pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  pixel9  \
# 0         107     118     127     134     139     143     146     150     153
# 1         155     157     156     156     156     157     156     158     158
# 2         187     188     188     187     187     186     187     188     187
# 3         211     211     212     212     211     210     211     210     210
# 4         164     167     170     172     176     179     180     184     185
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 27445     167     169     170     171     171     172     172     172     171
# 27446     133     135     138     141     143     144     144     145     145
# 27447     170     172     175     177     179     182     185     186     187
# 27448     149     151     153     157     159     161     164     165     168
# 27449     162     168     172     176     179     183     184     185     188
#
#        pixel10  ...  pixel775  pixel776  pixel777  pixel778  pixel779  \
# 0          156  ...       207       207       207       207       206
# 1          157  ...        69       149       128        87        94
# 2          186  ...       202       201       200       199       198
# 3          211  ...       235       234       233       231       230
# 4          186  ...        92       105       105       108       133
# ...        ...  ...       ...       ...       ...       ...       ...
# 27445      172  ...       215       215       211       208       211
# 27446      145  ...         0         0         1         4         4
# 27447      188  ...       221       228       229       228       229
# 27448      171  ...       108       165       167       163       159
# 27449      190  ...       235       234       234       233       231
#
#        pixel780  pixel781  pixel782  pixel783  pixel784
# 0           206       206       204       203       202
# 1           163       175       103       135       149
# 2           199       198       195       194       195
# 3           226       225       222       229       163
# 4           163       157       163       164       179
# ...         ...       ...       ...       ...       ...
# 27445       201       167       119        75        48
# 27446         0         0         0         0         0
# 27447       229       227       228       227       227
# 27448       153       147       148       139       196
# 27449       229       228       228       227       226
#
# [27450 rows x 784 columns]

# %%
y_test = df_test['label']
df_test.drop(['label'], axis=1, inplace=True)
df_test.head(-5)
# Out:
#       pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  pixel9  \
# 0        149     149     150     150     150     151     151     150     151
# 1        126     128     131     132     133     134     135     135     136
# 2         85      88      92      96     105     123     135     143     147
# 3        203     205     207     206     207     209     210     209     210
# 4        188     191     193     195     199     201     202     203     203
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 7162     130     131     131     134     133     135     137     136     136
# 7163     158     161     165     169     172     175     177     179     181
# 7164     141     144     146     149     153     156     158     161     161
# 7165     158     160     160     161     161     161     164     162     162
# 7166     169     173     177     181     183     186     189     191     194
#
#       pixel10  ...  pixel775  pixel776  pixel777  pixel778  pixel779  \
# 0         152  ...       138       148       127        89        82
# 1         138  ...        47       104       194       183       186
# 2         152  ...        68       166       242       227       230
# 3         209  ...       154       248       247       248       253
# 4         203  ...        26        40        64        48        29
# ...       ...  ...       ...       ...       ...       ...       ...
# 7162      137  ...       128       106       107        63        11
# 7163      184  ...        78       122       141       141       141
# 7164      161  ...       199       203       202       201       201
# 7165      161  ...       177       178       176       174       173
# 7166      195  ...        36        27        14        35        40
#
#       pixel780  pixel781  pixel782  pixel783  pixel784
# 0           96       106       112       120       107
# 1          184       184       184       182       180
# 2          227       226       225       224       222
# 3          236       230       240       253       255
# 4           46        49        46        46        53
# ...        ...       ...       ...       ...       ...
# 7162       147       194       182       176       124
# 7163       140       141       142       143       144
# 7164       201       200       200       201       201
# 7165       172       171       169       169       167
# 7166        15         8        27        42        41
#
# [7167 rows x 784 columns]

# %% [markdown]
# Define the size of image and its channel, batch size  and the number of epochs.

# %%
size  = 28
channels = 1
batch = 128
epochs = 100

# %% [markdown]
# Reshape the data to make images ready for **ImageDataGenerator**:
# > reshape(number of rows, img width, img height, channels)

# %%
X_train = df_train.values.reshape(df_train.shape[0], size, size, channels)
X_test = df_test.values.reshape(df_test.shape[0], size, size, channels)

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
# Out:
# X_train shape: (27455, 28, 28, 1)
# X_test shape: (7172, 28, 28, 1)

# %% [markdown]
# # 4- Data Augmentation
# Let's make augmentation on training data and only scaling validation and test data.

# %%
datagen = ImageDataGenerator(rescale=1./255,
                             zoom_range=0.2,
                             width_shift_range=.2, height_shift_range=.2,
                             rotation_range=30,
                             brightness_range=[0.8, 1.2],
                             horizontal_flip=True)

datagenRescale = ImageDataGenerator(rescale=1./255)

X_train = datagen.flow(X_train, y_train, batch_size=batch)

X_test = datagenRescale.flow(X_test, y_test)

# %%
alphabet = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
plt.figure(figsize=(15, 15))
for i in range(9):
    plt.subplot(3, 3, i+1)
    for X_batch, Y_batch in X_train:
        image = X_batch[i]
        plt.imshow(image, cmap='gray')
        plt.xlabel(alphabet[Y_batch[i]])
        break
plt.show()

# %% [markdown]
# # 5- Setup Callbacks

# %%
checkpoint_filepath = 'best_model.hdf5'

callback_checkpoint = ModelCheckpoint(filepath=checkpoint_filepath, save_weights_only=False, monitor='val_accuracy', mode='max', save_best_only=True)
callback_learningrate = ReduceLROnPlateau(monitor='loss', mode='min', min_delta=0.01, patience=3, factor=.75, min_lr=0.00001, verbose=1)

callbacks = [callback_checkpoint, callback_learningrate]

# %% [markdown]
# # 6- Desighn the Neural Network

# %%
Model = Sequential([Conv2D(filters=32,  kernel_size=(3,3), activation="relu", input_shape=(size,size,channels)),
                    MaxPool2D(2,2, padding='same'),
                    Dropout(0.2),
                 
                    Conv2D(filters=128,  kernel_size=(3,3), activation="relu"),
                    MaxPool2D(2,2, padding='same'),
                    Dropout(0.2),
                
                    Conv2D(filters=512, kernel_size=(3,3), activation="relu"),
                    MaxPool2D(2,2, padding='same'),
                    Dropout(0.2),
                    
                    
                    Flatten(),
                    
                    Dense(units=4096, activation="relu"),                 
                    Dropout(0.2),
                    
                    Dense(units=1024, activation="relu"),
                    Dropout(0.2),
                                  
                    Dense(units=256, activation="relu"),
                    Dropout(0.2),
                    
                    Dense(units=25, activation="softmax"),
])


Model.compile(optimizer='adam', loss="sparse_categorical_crossentropy", metrics=["accuracy"])


Model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 128)       36992
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 512)         590336
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              8392704
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              4195328
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               262400
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 25)                6425
# =================================================================
# Total params: 13,484,505
# Trainable params: 13,484,505
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 7- Let's train

# %%
history = Model.fit(X_train, validation_data=X_test, epochs=epochs, callbacks=callbacks)
# Out:
# Epoch 1/100
# 215/215 [==============================] - 18s 73ms/step - loss: 3.1596 - accuracy: 0.0521 - val_loss: 2.7508 - val_accuracy: 0.1097
# Epoch 2/100
# 215/215 [==============================] - 15s 69ms/step - loss: 2.4846 - accuracy: 0.1848 - val_loss: 1.7116 - val_accuracy: 0.3880
# Epoch 3/100
# 215/215 [==============================] - 15s 71ms/step - loss: 1.6351 - accuracy: 0.4257 - val_loss: 0.8391 - val_accuracy: 0.6976
# Epoch 4/100
# 215/215 [==============================] - 15s 69ms/step - loss: 1.1453 - accuracy: 0.5941 - val_loss: 0.6032 - val_accuracy: 0.7892
# Epoch 5/100
# 215/215 [==============================] - 16s 72ms/step - loss: 0.8876 - accuracy: 0.6870 - val_loss: 0.5129 - val_accuracy: 0.8108
# Epoch 6/100
# 215/215 [==============================] - 15s 71ms/step - loss: 0.7379 - accuracy: 0.7417 - val_loss: 0.3645 - val_accuracy: 0.8624
# Epoch 7/100
# 215/215 [==============================] - 15s 72ms/step - loss: 0.6264 - accuracy: 0.7823 - val_loss: 0.2545 - val_accuracy: 0.9163
# Epoch 8/100
# 215/215 [==============================] - 15s 70ms/step - loss: 0.5515 - accuracy: 0.8098 - val_loss: 0.2406 - val_accuracy: 0.9095
# Epoch 9/100
# 215/215 [==============================] - 15s 70ms/step - loss: 0.4865 - accuracy: 0.8351 - val_loss: 0.2477 - val_accuracy: 0.9080
# Epoch 10/100
# 215/215 [==============================] - 15s 71ms/step - loss: 0.4637 - accuracy: 0.8449 - val_loss: 0.1776 - val_accuracy: 0.9303
# Epoch 11/100
# 215/215 [==============================] - 15s 69ms/step - loss: 0.4070 - accuracy: 0.8630 - val_loss: 0.1585 - val_accuracy: 0.9399
# Epoch 12/100
# 215/215 [==============================] - 16s 73ms/step - loss: 0.3896 - accuracy: 0.8699 - val_loss: 0.1406 - val_accuracy: 0.9523
# Epoch 13/100
# 215/215 [==============================] - 15s 71ms/step - loss: 0.3450 - accuracy: 0.8829 - val_loss: 0.1022 - val_accuracy: 0.9646
# Epoch 14/100
# 215/215 [==============================] - 16s 72ms/step - loss: 0.3247 - accuracy: 0.8919 - val_loss: 0.0958 - val_accuracy: 0.9658
# Epoch 15/100
# 215/215 [==============================] - 15s 70ms/step - loss: 0.3141 - accuracy: 0.8947 - val_loss: 0.0914 - val_accuracy: 0.9665
# Epoch 16/100
# 215/215 [==============================] - 16s 72ms/step - loss: 0.2886 - accuracy: 0.9054 - val_loss: 0.1437 - val_accuracy: 0.9445
# Epoch 17/100
# 215/215 [==============================] - 15s 72ms/step - loss: 0.2914 - accuracy: 0.9056 - val_loss: 0.0992 - val_accuracy: 0.9714
# Epoch 18/100
# 215/215 [==============================] - 16s 73ms/step - loss: 0.2754 - accuracy: 0.9094 - val_loss: 0.0839 - val_accuracy: 0.9707
# Epoch 19/100
# 215/215 [==============================] - 16s 75ms/step - loss: 0.2556 - accuracy: 0.9147 - val_loss: 0.0968 - val_accuracy: 0.9682
# Epoch 20/100
# 215/215 [==============================] - 16s 75ms/step - loss: 0.2586 - accuracy: 0.9161 - val_loss: 0.0776 - val_accuracy: 0.9731
# Epoch 21/100
# 215/215 [==============================] - 16s 73ms/step - loss: 0.2363 - accuracy: 0.9212 - val_loss: 0.0970 - val_accuracy: 0.9670
# Epoch 22/100
# 215/215 [==============================] - 16s 73ms/step - loss: 0.2342 - accuracy: 0.9220 - val_loss: 0.0974 - val_accuracy: 0.9632
# Epoch 23/100
# 215/215 [==============================] - 16s 74ms/step - loss: 0.2164 - accuracy: 0.9303 - val_loss: 0.0533 - val_accuracy: 0.9861
# Epoch 24/100
# 215/215 [==============================] - 16s 73ms/step - loss: 0.2276 - accuracy: 0.9244 - val_loss: 0.0977 - val_accuracy: 0.9642
# Epoch 25/100
# 215/215 [==============================] - 16s 74ms/step - loss: 0.2120 - accuracy: 0.9312 - val_loss: 0.0521 - val_accuracy: 0.9842
# Epoch 26/100
# 215/215 [==============================] - 15s 72ms/step - loss: 0.1900 - accuracy: 0.9390 - val_loss: 0.0303 - val_accuracy: 0.9918
# Epoch 27/100
# 215/215 [==============================] - 15s 72ms/step - loss: 0.2111 - accuracy: 0.9324 - val_loss: 0.0316 - val_accuracy: 0.9893
# Epoch 28/100
# 215/215 [==============================] - 15s 69ms/step - loss: 0.1930 - accuracy: 0.9378 - val_loss: 0.0556 - val_accuracy: 0.9854
# Epoch 29/100
# 215/215 [==============================] - 16s 73ms/step - loss: 0.1790 - accuracy: 0.9403 - val_loss: 0.0916 - val_accuracy: 0.9656
# Epoch 30/100
# 215/215 [==============================] - 15s 69ms/step - loss: 0.1919 - accuracy: 0.9401 - val_loss: 0.0483 - val_accuracy: 0.9824
# Epoch 31/100
# 215/215 [==============================] - 15s 70ms/step - loss: 0.1844 - accuracy: 0.9403 - val_loss: 0.0348 - val_accuracy: 0.9914
# Epoch 32/100
# 215/215 [==============================] - 15s 68ms/step - loss: 0.1850 - accuracy: 0.9422 - val_loss: 0.0502 - val_accuracy: 0.9820
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0007500000356230885.
# Epoch 33/100
# 215/215 [==============================] - 15s 71ms/step - loss: 0.1543 - accuracy: 0.9494 - val_loss: 0.0445 - val_accuracy: 0.9861
# Epoch 34/100
# 215/215 [==============================] - 15s 69ms/step - loss: 0.1514 - accuracy: 0.9504 - val_loss: 0.0281 - val_accuracy: 0.9918
# Epoch 35/100
# 215/215 [==============================] - 15s 69ms/step - loss: 0.1474 - accuracy: 0.9526 - val_loss: 0.0473 - val_accuracy: 0.9845
# Epoch 36/100
# 215/215 [==============================] - 16s 73ms/step - loss: 0.1465 - accuracy: 0.9517 - val_loss: 0.0245 - val_accuracy: 0.9919
# Epoch 37/100
# 215/215 [==============================] - 15s 69ms/step - loss: 0.1368 - accuracy: 0.9551 - val_loss: 0.0514 - val_accuracy: 0.9828
# Epoch 38/100
# 215/215 [==============================] - 15s 72ms/step - loss: 0.1444 - accuracy: 0.9543 - val_loss: 0.0271 - val_accuracy: 0.9900
# Epoch 39/100
# 215/215 [==============================] - 15s 69ms/step - loss: 0.1346 - accuracy: 0.9556 - val_loss: 0.0413 - val_accuracy: 0.9858
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.0005625000048894435.
# Epoch 40/100
# 215/215 [==============================] - 15s 71ms/step - loss: 0.1260 - accuracy: 0.9591 - val_loss: 0.0275 - val_accuracy: 0.9912
# Epoch 41/100
# 215/215 [==============================] - 15s 70ms/step - loss: 0.1173 - accuracy: 0.9640 - val_loss: 0.0214 - val_accuracy: 0.9936
# Epoch 42/100
# 215/215 [==============================] - 15s 72ms/step - loss: 0.1104 - accuracy: 0.9634 - val_loss: 0.0290 - val_accuracy: 0.9887
# Epoch 43/100
# 215/215 [==============================] - 15s 69ms/step - loss: 0.1059 - accuracy: 0.9658 - val_loss: 0.0199 - val_accuracy: 0.9926
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.0004218749818392098.
# Epoch 44/100
# 215/215 [==============================] - 15s 71ms/step - loss: 0.1056 - accuracy: 0.9663 - val_loss: 0.0237 - val_accuracy: 0.9908
# Epoch 45/100
# 215/215 [==============================] - 15s 69ms/step - loss: 0.1023 - accuracy: 0.9664 - val_loss: 0.0157 - val_accuracy: 0.9948
# Epoch 46/100
# 215/215 [==============================] - 16s 72ms/step - loss: 0.0931 - accuracy: 0.9689 - val_loss: 0.0251 - val_accuracy: 0.9898
# Epoch 47/100
# 215/215 [==============================] - 15s 69ms/step - loss: 0.0916 - accuracy: 0.9707 - val_loss: 0.0227 - val_accuracy: 0.9907
# Epoch 48/100
# 215/215 [==============================] - 15s 71ms/step - loss: 0.0918 - accuracy: 0.9700 - val_loss: 0.0213 - val_accuracy: 0.9916
# Epoch 49/100
# 215/215 [==============================] - 15s 69ms/step - loss: 0.1035 - accuracy: 0.9675 - val_loss: 0.0300 - val_accuracy: 0.9904
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 0.00031640623637940735.
# Epoch 50/100
# 215/215 [==============================] - 15s 70ms/step - loss: 0.0882 - accuracy: 0.9717 - val_loss: 0.0143 - val_accuracy: 0.9957
# Epoch 51/100
# 215/215 [==============================] - 15s 70ms/step - loss: 0.0912 - accuracy: 0.9707 - val_loss: 0.0259 - val_accuracy: 0.9897
# Epoch 52/100
# 215/215 [==============================] - 15s 70ms/step - loss: 0.0903 - accuracy: 0.9715 - val_loss: 0.0239 - val_accuracy: 0.9912
# Epoch 53/100
# 215/215 [==============================] - 15s 69ms/step - loss: 0.0889 - accuracy: 0.9697 - val_loss: 0.0179 - val_accuracy: 0.9951
# Epoch 54/100
# 215/215 [==============================] - 15s 70ms/step - loss: 0.0927 - accuracy: 0.9702 - val_loss: 0.0126 - val_accuracy: 0.9964
# Epoch 55/100
# 215/215 [==============================] - 15s 69ms/step - loss: 0.0876 - accuracy: 0.9729 - val_loss: 0.0154 - val_accuracy: 0.9955
#
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 0.00023730468819849193.
# Epoch 56/100
# 215/215 [==============================] - 15s 69ms/step - loss: 0.0736 - accuracy: 0.9754 - val_loss: 0.0156 - val_accuracy: 0.9943
# Epoch 57/100
# 215/215 [==============================] - 16s 73ms/step - loss: 0.0717 - accuracy: 0.9759 - val_loss: 0.0143 - val_accuracy: 0.9947
# Epoch 58/100
# 215/215 [==============================] - 15s 69ms/step - loss: 0.0675 - accuracy: 0.9780 - val_loss: 0.0158 - val_accuracy: 0.9947
# Epoch 59/100
# 215/215 [==============================] - 16s 73ms/step - loss: 0.0709 - accuracy: 0.9769 - val_loss: 0.0208 - val_accuracy: 0.9918
# Epoch 60/100
# 215/215 [==============================] - 15s 69ms/step - loss: 0.0773 - accuracy: 0.9743 - val_loss: 0.0226 - val_accuracy: 0.9936
# Epoch 61/100
# 215/215 [==============================] - 15s 70ms/step - loss: 0.0741 - accuracy: 0.9764 - val_loss: 0.0181 - val_accuracy: 0.9943
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 0.00017797851614886895.
# Epoch 62/100
# 215/215 [==============================] - 15s 70ms/step - loss: 0.0685 - accuracy: 0.9770 - val_loss: 0.0175 - val_accuracy: 0.9929
# Epoch 63/100
# 215/215 [==============================] - 15s 71ms/step - loss: 0.0724 - accuracy: 0.9764 - val_loss: 0.0153 - val_accuracy: 0.9950
# Epoch 64/100
# 215/215 [==============================] - 15s 69ms/step - loss: 0.0682 - accuracy: 0.9788 - val_loss: 0.0134 - val_accuracy: 0.9948
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 0.0001334838816546835.
# Epoch 65/100
# 215/215 [==============================] - 15s 71ms/step - loss: 0.0665 - accuracy: 0.9790 - val_loss: 0.0156 - val_accuracy: 0.9957
# Epoch 66/100
# 215/215 [==============================] - 15s 69ms/step - loss: 0.0602 - accuracy: 0.9800 - val_loss: 0.0156 - val_accuracy: 0.9947
# Epoch 67/100
# 215/215 [==============================] - 15s 71ms/step - loss: 0.0620 - accuracy: 0.9789 - val_loss: 0.0215 - val_accuracy: 0.9934
#
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 0.00010011290578404441.
# Epoch 68/100
# 215/215 [==============================] - 15s 68ms/step - loss: 0.0589 - accuracy: 0.9814 - val_loss: 0.0158 - val_accuracy: 0.9955
# Epoch 69/100
# 215/215 [==============================] - 15s 71ms/step - loss: 0.0612 - accuracy: 0.9789 - val_loss: 0.0206 - val_accuracy: 0.9943
# Epoch 70/100
# 215/215 [==============================] - 15s 69ms/step - loss: 0.0572 - accuracy: 0.9806 - val_loss: 0.0143 - val_accuracy: 0.9960
# Epoch 71/100
# 215/215 [==============================] - 15s 68ms/step - loss: 0.0580 - accuracy: 0.9804 - val_loss: 0.0101 - val_accuracy: 0.9967
#
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 7.508467933803331e-05.
# Epoch 72/100
# 215/215 [==============================] - 16s 72ms/step - loss: 0.0581 - accuracy: 0.9819 - val_loss: 0.0120 - val_accuracy: 0.9965
# Epoch 73/100
# 215/215 [==============================] - 15s 71ms/step - loss: 0.0540 - accuracy: 0.9819 - val_loss: 0.0125 - val_accuracy: 0.9961
# Epoch 74/100
# 215/215 [==============================] - 15s 71ms/step - loss: 0.0575 - accuracy: 0.9836 - val_loss: 0.0140 - val_accuracy: 0.9944
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 5.6313510867767036e-05.
# Epoch 75/100
# 215/215 [==============================] - 15s 70ms/step - loss: 0.0564 - accuracy: 0.9818 - val_loss: 0.0160 - val_accuracy: 0.9950
# Epoch 76/100
# 215/215 [==============================] - 15s 69ms/step - loss: 0.0591 - accuracy: 0.9817 - val_loss: 0.0128 - val_accuracy: 0.9962
# Epoch 77/100
# 215/215 [==============================] - 15s 68ms/step - loss: 0.0535 - accuracy: 0.9820 - val_loss: 0.0143 - val_accuracy: 0.9958
#
# Epoch 00077: ReduceLROnPlateau reducing learning rate to 4.223513315082528e-05.
# Epoch 78/100
# 215/215 [==============================] - 15s 71ms/step - loss: 0.0555 - accuracy: 0.9821 - val_loss: 0.0132 - val_accuracy: 0.9955
# Epoch 79/100
# 215/215 [==============================] - 15s 71ms/step - loss: 0.0568 - accuracy: 0.9815 - val_loss: 0.0152 - val_accuracy: 0.9950
# Epoch 80/100
# 215/215 [==============================] - 15s 67ms/step - loss: 0.0520 - accuracy: 0.9812 - val_loss: 0.0120 - val_accuracy: 0.9961
#
# Epoch 00080: ReduceLROnPlateau reducing learning rate to 3.167634986311896e-05.
# Epoch 81/100
# 215/215 [==============================] - 15s 71ms/step - loss: 0.0501 - accuracy: 0.9826 - val_loss: 0.0114 - val_accuracy: 0.9962
# Epoch 82/100
# 215/215 [==============================] - 15s 70ms/step - loss: 0.0538 - accuracy: 0.9838 - val_loss: 0.0126 - val_accuracy: 0.9958
# Epoch 83/100
# 215/215 [==============================] - 15s 71ms/step - loss: 0.0478 - accuracy: 0.9850 - val_loss: 0.0129 - val_accuracy: 0.9960
#
# Epoch 00083: ReduceLROnPlateau reducing learning rate to 2.3757263079460245e-05.
# Epoch 84/100
# 215/215 [==============================] - 15s 69ms/step - loss: 0.0502 - accuracy: 0.9827 - val_loss: 0.0120 - val_accuracy: 0.9962
# Epoch 85/100
# 215/215 [==============================] - 15s 71ms/step - loss: 0.0515 - accuracy: 0.9840 - val_loss: 0.0116 - val_accuracy: 0.9962
# Epoch 86/100
# 215/215 [==============================] - 15s 70ms/step - loss: 0.0543 - accuracy: 0.9815 - val_loss: 0.0134 - val_accuracy: 0.9957
#
# Epoch 00086: ReduceLROnPlateau reducing learning rate to 1.781794799171621e-05.
# Epoch 87/100
# 215/215 [==============================] - 15s 71ms/step - loss: 0.0505 - accuracy: 0.9816 - val_loss: 0.0128 - val_accuracy: 0.9958
# Epoch 88/100
# 215/215 [==============================] - 15s 71ms/step - loss: 0.0477 - accuracy: 0.9842 - val_loss: 0.0133 - val_accuracy: 0.9954
# Epoch 89/100
# 215/215 [==============================] - 16s 73ms/step - loss: 0.0542 - accuracy: 0.9831 - val_loss: 0.0124 - val_accuracy: 0.9958
#
# Epoch 00089: ReduceLROnPlateau reducing learning rate to 1.3363460311666131e-05.
# Epoch 90/100
# 215/215 [==============================] - 15s 70ms/step - loss: 0.0525 - accuracy: 0.9832 - val_loss: 0.0121 - val_accuracy: 0.9960
# Epoch 91/100
# 215/215 [==============================] - 15s 72ms/step - loss: 0.0510 - accuracy: 0.9838 - val_loss: 0.0134 - val_accuracy: 0.9958
# Epoch 92/100
# 215/215 [==============================] - 15s 70ms/step - loss: 0.0522 - accuracy: 0.9835 - val_loss: 0.0111 - val_accuracy: 0.9962
#
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 1.0022595233749598e-05.
# Epoch 93/100
# 215/215 [==============================] - 16s 72ms/step - loss: 0.0512 - accuracy: 0.9837 - val_loss: 0.0109 - val_accuracy: 0.9962
# Epoch 94/100
# 215/215 [==============================] - 15s 72ms/step - loss: 0.0518 - accuracy: 0.9826 - val_loss: 0.0114 - val_accuracy: 0.9962
# Epoch 95/100
# 215/215 [==============================] - 15s 71ms/step - loss: 0.0535 - accuracy: 0.9830 - val_loss: 0.0121 - val_accuracy: 0.9961
#
# Epoch 00095: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 96/100
# 215/215 [==============================] - 15s 71ms/step - loss: 0.0521 - accuracy: 0.9833 - val_loss: 0.0108 - val_accuracy: 0.9962
# Epoch 97/100
# 215/215 [==============================] - 15s 72ms/step - loss: 0.0531 - accuracy: 0.9825 - val_loss: 0.0113 - val_accuracy: 0.9962
# Epoch 98/100
# 215/215 [==============================] - 15s 69ms/step - loss: 0.0537 - accuracy: 0.9828 - val_loss: 0.0110 - val_accuracy: 0.9962
# Epoch 99/100
# 215/215 [==============================] - 16s 72ms/step - loss: 0.0478 - accuracy: 0.9841 - val_loss: 0.0109 - val_accuracy: 0.9961
# Epoch 100/100
# 215/215 [==============================] - 15s 72ms/step - loss: 0.0529 - accuracy: 0.9829 - val_loss: 0.0116 - val_accuracy: 0.9960

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(len(acc))

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # 8- Let's evaluate

# %%
score = Model.evaluate(X_test) 

print('Test loss:', score[0]) 
print('Test accuracy:', score[1])
# Out:
# 225/225 [==============================] - 1s 6ms/step - loss: 0.0116 - accuracy: 0.9960
# Test loss: 0.011640181764960289
# Test accuracy: 0.9959564805030823

# %% [markdown]
# # 9- Confusion Matrix

# %%
df_test = pd.read_csv('../input/sign-language-mnist/sign_mnist_test/sign_mnist_test.csv')
y_test = df_test['label']
df_test.drop(['label'], axis=1, inplace=True)
X_test = df_test.values.reshape(df_test.shape[0], size, size, channels)

# %%
y_pred = np.argmax(Model.predict(X_test),axis = 1)

# %%
from sklearn.metrics import confusion_matrix
CM = confusion_matrix(y_test, y_pred)
plt.figure(figsize = (15,15))
sns.heatmap(CM, annot=True, cmap="Blues", fmt = 'g')
plt.xlabel("Predicted Classes")
plt.ylabel("True Classes")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# # 10- Let's Check

# %%
plt.figure(figsize=(15,15))
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(X_test[i],cmap='gray')
    plt.ylabel(f"True: {alphabet[y_test[i]]}")
    plt.xlabel(f"Predicted: {alphabet[y_pred[i]]}")
    
plt.show()
